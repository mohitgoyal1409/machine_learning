# %% [markdown]
# <a href="https://colab.research.google.com/github/mohitgoyal1409/machine_learning/blob/main/32_Regression_Metrics_%7C_MSE%2C_MAE_%26_RMSE_%7C_R2_Score_%26_Adjusted_R2_Score.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('placements.csv')

# %%
df.head()
# Out:
#    cgpa  package
# 0  6.89     3.26
# 1  5.12     1.98
# 2  7.82     3.25
# 3  7.42     3.67
# 4  6.94     3.57

# %%
plt.scatter(df['cgpa'],df['package'])
plt.xlabel('cgpa')
plt.ylabel('package')
plt
# Out:
# <module 'matplotlib.pyplot' from '/usr/local/lib/python3.12/dist-packages/matplotlib/pyplot.py'>

# %%
X = df.iloc[:,0:1]
y = df.iloc[:,-1]

# %%
y
# Out:
# 0      3.26
# 1      1.98
# 2      3.25
# 3      3.67
# 4      3.57
#        ...
# 195    2.46
# 196    2.57
# 197    3.24
# 198    3.96
# 199    2.33
# Name: package, Length: 200, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=2)

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
plt.scatter(X_train,y_train,color='blue')
plt.plot(X_train,lr.predict(X_train),color='red')
plt.xlabel('cgpa')
plt.ylabel('package')
# Out:
# Text(0, 0.5, 'package')

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
y_pred = lr.predict(X_test)

# %%
y_test.values
# Out:
# array([4.1 , 3.49, 2.08, 2.33, 1.94, 1.48, 1.86, 3.09, 4.21, 2.87, 3.65,
#        4.  , 2.89, 2.6 , 2.99, 3.25, 1.86, 3.67, 2.37, 3.42, 2.48, 3.65,
#        2.6 , 2.83, 4.08, 2.56, 3.58, 3.81, 4.09, 2.01, 3.63, 2.92, 3.51,
#        1.94, 2.21, 3.34, 3.34, 3.23, 2.01, 2.61])

# %%
print("MAE", mean_absolute_error(y_test,y_pred))
print("MSE", mean_squared_error(y_test,y_pred))
print("RMSE", np.sqrt(mean_squared_error(y_test,y_pred)))
print("r2_score" , r2_score(y_test,y_pred))
# Out:
# MAE 0.2884710931878175
# MSE 0.12129235313495527
# RMSE 0.34827051717731616
# r2_score 0.780730147510384

# %%
X_test.shape
# Out:
# (40, 1)

# %%
r2 = r2_score(y_test,y_pred)
1 - ((1-r2)*(40-1)/(40-2))
# Out:
# 0.7749598882343415

# %%
new_df1 = df.copy()
new_df1['random_feature'] = np.random.random(200)

new_df1 = new_df1[['cgpa','random_feature','package']]
new_df1.head()
# Out:
#    cgpa  random_feature  package
# 0  6.89        0.339201     3.26
# 1  5.12        0.272318     1.98
# 2  7.82        0.535531     3.25
# 3  7.42        0.354319     3.67
# 4  6.94        0.352799     3.57

# %%
plt.scatter(new_df1['random_feature'],new_df1['package'])
plt.xlabel('cgpa')
plt.ylabel('package')
# Out:
# Text(0, 0.5, 'package')

# %%
X = new_df1.iloc[:,0:2]
y = new_df1.iloc[:,-1]

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=2)

# %%
lr = LinearRegression()
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(X_test)

# %%
print("MAE", mean_absolute_error(y_test,y_pred))
print("MSE", mean_squared_error(y_test,y_pred))
print("RMSE", np.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# MAE 0.29091095896310604
# MSE 0.1241866225573857
# RMSE 0.35240122383071504

# %%
print("r2_score" , r2_score(y_test,y_pred))
# Out:
# r2_score 0.7754979460325595

# %%
r2 = r2_score(y_test,y_pred)
1 - ((1-r2)*(40-1)/(40-2))
# Out:
# 0.7695899972439426

# %% [markdown]
# # adding iq column

# %%
new_df2 = df.copy()
new_df2['iq'] = new_df2['package']+ (np.random.randint(-12,12,200)/10)
new_df2  = new_df2[['cgpa','iq','package']]

# %%
new_df2.sample(5)
# Out:
#      cgpa    iq  package
# 15   7.25  2.83     3.23
# 126  5.91  3.70     2.60
# 55   8.20  2.99     3.39
# 116  9.04  2.43     3.33
# 2    7.82  2.85     3.25

# %%
plt.scatter(new_df2['iq'],new_df2['package'])
plt.xlabel('cgpa')
plt.ylabel('package')
# Out:
# Text(0, 0.5, 'package')

# %%
X = new_df2.iloc[:,0:2]
y = new_df2.iloc[:,-1]

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=2)

# %%
lr = LinearRegression()
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(X_test)

# %%
print("MAE", mean_absolute_error(y_test,y_pred))
print("MSE", mean_squared_error(y_test,y_pred))
print("RMSE", np.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# MAE 0.27276359849342097
# MSE 0.10455652141207745
# RMSE 0.32335200851715373

# %%
print("r2_score" , r2_score(y_test,y_pred))
# Out:
# r2_score 0.8109848441859727

# %%
1 - ((1-r2_score(y_test,y_pred))*(40-1)/(40-3))
# Out:
# 0.8007678087365658
