# %% [markdown]
# <a href="https://colab.research.google.com/github/mohitgoyal1409/machine_learning/blob/main/4_univariate_data_understand.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
#  # catorgical data
#  # 1. Countplot

# %%
# countplot
import pandas as pd
import seaborn as sns
df = pd.read_csv('train.csv')
df
# sns.countplot(x = df['Survived'])
# sns.countplot(x = df['Pclass'])
sns.countplot(x = df['Sex'])
# Out:
# <Axes: xlabel='Sex', ylabel='count'>

# %%
df['Survived'].value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
df['Survived'].value_counts().plot(kind = 'bar')
# Out:
# <Axes: xlabel='Survived'>

# %% [markdown]
# # 2. piechart

# %%
df['Survived'].value_counts().plot(kind = 'pie', autopct = '%.2f')
# df['Pclass'].value_counts().plot(kind = 'pie', autopct = '%.2f')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# # Numerical data

# %% [markdown]
# # 1. Histogram

# %%
import matplotlib.pyplot as plt
plt.hist(df['Age'])
# df['Age'].value_counts().sum()
# Out:
# (array([ 54.,  46., 177., 169., 118.,  70.,  45.,  24.,   9.,   2.]),
#  array([ 0.42 ,  8.378, 16.336, 24.294, 32.252, 40.21 , 48.168, 56.126,
#         64.084, 72.042, 80.   ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# # 2. Dist plot

# %%
sns.displot(df['Age'])

# %% [markdown]
# # 3.boxplot

# %%
sns.boxplot(df['Fare'])
# Out:
# <Axes: ylabel='Fare'>
